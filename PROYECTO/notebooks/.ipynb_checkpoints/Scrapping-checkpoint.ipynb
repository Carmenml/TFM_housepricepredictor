# %%
#Libraries

# %%
import requests
from bs4 import BeautifulSoup as bs
import time
import random
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
headers = {
    "accept": 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    "accept-encoding": 'gzip, deflate, br',
    "accept-language": 'es-ES,es;q=0.9,en;q=0.8',
    "cache-control": 'max-age=0',
    "dnt": "1",
    "sec-ch-ua": '"Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"',
    "sec-ch-ua-mobile": '?0',
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": 'document',
    "sec-fetch-mode": 'navigate',
    "sec-fetch-site": 'same-origin',
    "sec-fetch-user": '?1',
    "upgrade-insecure-requests": '1',
    "user-agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36'
}

# %%
id_inmueble = "93112134"
id_inmueble1 = "93100056"
id_inmueble2 = "95621821"

# %%
def request_piso(id_inmueble, headers="",proxy=""):
    url = f"https://www.idealista.com/inmueble/{id_inmueble}/"
    r = requests.get(url, headers=headers)
    time.sleep(random.randint(1,3)*random.random())
    return r

# %%
r = request_piso(id_inmueble, headers=headers)

# %%
r
# Out:
# <Response [200]>

# %%
soup = bs(r.text, "lxml")

# %%
def info_inmueble():
    
    scripts = soup.find_all("script")
    
    for script in scripts:
        if "var config" in str(script):
            break
    latitude = float(str(script).split("latitude")[1].split(",")[0].split()[1].replace("'", ""))        
    longitude = float(str(script).split("latitude")[1].split(",")[1].strip().split()[1].replace("'", ""))
    
    scripts = soup.find_all("script")
    
    for script in scripts:
        if "var utag_data" in str(script):
            break
    
    data = json.loads(str(script).split("var utag_data =")[1].split(";")[0].strip())
    
    titulo = soup.find("h1").text.strip()
    localizacion = soup.find("span",{"class":"main-info__title-block"}).find("span").text.strip()
    price = data["ad"]["price"]
    energy_certification = data["ad"]["energyCertification"]["type"]
    basic_characteristics = data["ad"]["characteristics"]
    room_number = data["ad"]["characteristics"]["roomNumber"]
    bath_number = data["ad"]["characteristics"]["bathNumber"]
    
    try:
        has_garden = data["ad"]["characteristics"]["hasGarden"]
    except:
        has_garden = None
        
    try:
        has_terrace = data["ad"]["characteristics"]["hasTerrace"]
    except:
        has_terrace = None
        
    try:
        has_parking = data["ad"]["characteristics"]["hasParking"]
    except:
        has_parking = None
        
    try:
        has_swimmingpool = data["ad"]["characteristics"]["hasSwimmingPool"]
    except:
        has_swimmingpool = None
        
    try:
        has_lift = data["ad"]["characteristics"]["hasLift"]
    except:
        has_lift = None
        
    constructed_area = data["ad"]["characteristics"]["constructedArea"]
    is_new_development = data["ad"]["condition"]["isNewDevelopment"]
    is_needs_renovating = data["ad"]["condition"]["isNeedsRenovating"]
    is_goog_condition = data["ad"]["condition"]["isGoodCondition"]
    
    lista = [titulo, localizacion, latitude, longitude, price, energy_certification, basic_characteristics,
            room_number, bath_number,has_garden, has_terrace, has_parking, has_swimmingpool, has_lift, constructed_area,
            is_new_development, is_needs_renovating, is_goog_condition]
    
    time.sleep(random.randint(1,3)*random.random())
    return lista

# %%
info_inmueble()
# Out:
# ['Casa o chalet independiente en venta en Quintana, 3',
#  'Ciudad Jardín, Las Palmas de Gran Canaria',
#  28.1266405,
#  -15.4342363,
#  '1450000',
#  'g',
#  {'roomNumber': '6',
#   'bathNumber': '5',
#   'hasParking': '1',
#   'hasGarden': '1',
#   'hasTerrace': '1',
#   'constructedArea': '353'},
#  '6',
#  '5',
#  '1',
#  '1',
#  '1',
#  None,
#  None,
#  '353',
#  '0',
#  '0',
#  '1']

# %%
#identificación de IDS

# %%
busqueda = "churriana malaga"
busqueda = busqueda.replace(" ","_")

x = 1
ids = []

while True:
    url = f"https://www.idealista.com/buscar/venta-viviendas/{busqueda}/pagina-{x}.htm"
    
    r = requests.get(url, headers = headers)
    soup = bs(r.text, "lxml")
    
    pagina_actual = int(soup.find("main", {"class":"listing-items"}).find("div", {"class":"pagination"}).find("li", {"class":"selected"}).text)
    
    if x == pagina_actual:
        articles = soup.find("main", {"class":"listing-items"}).find_all("article")
    
    else:
        break
        
    x = x+1
        
    for article in articles:
        id_inmueble = article.get("data-adid")
        
        ids.append(id_inmueble)
        
    time.sleep(random.randint(1,3)*random.random())

# %%
len(ids)
# Out:
# 342

# %%
#voy a hacer un csv con la columna de ids sacada.
columns_ids = ["id"]
df_ids = pd.DataFrame(ids, columns= columns_ids)

df_ids.to_csv('ids_churriana-malaga.csv')

# %%
df = pd.read_csv('ids_churriana-malaga.csv')

# %%
df
# Out:
#      Unnamed: 0        id
# 0             0  98811885
# 1             1  95931901
# 2             2  98750560
# 3             3  98942399
# 4             4  97949995
# 5             5  95499926
# 6             6  99338182
# 7             7  98719316
# 8             8  98822161
# 9             9  99045241
# 10           10  98960009
# 11           11  96318991
# 12           12  99129858
# 13           13  97702649
# 14           14  99417058
# 15           15  99343448
# 16           16  99213688
# 17           17  97366293
# 18           18  98655741
# 19           19  97009508
# 20           20  96966283
# 21           21  96264226
# 22           22  99267735
# 23           23  99288860
# 24           24  99288592
# 25           25  98893481
# 26           26  98873419
# 27           27  98557538
# 28           28  97527823
# 29           29  97143561
# ..          ...       ...
# 312         312  99262937
# 313         313  93457620
# 314         314  96792653
# 315         315  98648767
# 316         316  94360163
# 317         317  88563249
# 318         318  99172502
# 319         319  98579053
# 320         320  98238304
# 321         321  93931595
# 322         322  95865870
# 323         323  94211486
# 324         324  99099163
# 325         325  97792702
# 326         326  93466795
# 327         327  99342265
# 328         328  97012860
# 329         329  89296108
# 330         330  98337314
# 331         331  90026358
# 332         332  98595144
# 333         333  98414963
# 334         334  96305785
# 335         335  98790947
# 336         336  96133949
# 337         337  99156554
# 338         338  99216120
# 339         339  98986313
# 340         340  98502872
# 341         341  92113328
#
# [342 rows x 2 columns]

# %%
list_ids = df["id"].tolist()

# %%
list_ids
# Out:
# [98811885,
#  95931901,
#  98750560,
#  98942399,
#  97949995,
#  95499926,
#  99338182,
#  98719316,
#  98822161,
#  99045241,
#  98960009,
#  96318991,
#  99129858,
#  97702649,
#  99417058,
#  99343448,
#  99213688,
#  97366293,
#  98655741,
#  97009508,
#  96966283,
#  96264226,
#  99267735,
#  99288860,
#  99288592,
#  98893481,
#  98873419,
#  98557538,
#  97527823,
#  97143561,
#  96459404,
#  98801384,
#  94804199,
#  99026825,
#  97210242,
#  98124262,
#  97634541,
#  97124225,
#  99288393,
#  98281131,
#  97431795,
#  97008087,
#  99199774,
#  99101562,
#  98345112,
#  97283582,
#  92690638,
#  86709875,
#  95767352,
#  94620374,
#  91773542,
#  98616786,
#  97317917,
#  97597379,
#  99375174,
#  99285180,
#  98961792,
#  98076552,
#  98690124,
#  95011891,
#  89127955,
#  96830639,
#  81246662,
#  96481816,
#  81395404,
#  98635787,
#  99124298,
#  98948359,
#  98483847,
#  99282287,
#  97741878,
#  99354548,
#  99309774,
#  98904108,
#  36820701,
#  98490064,
#  99362718,
#  98606809,
#  97434759,
#  99261963,
#  99212700,
#  98980672,
#  98504063,
#  99339984,
#  98951616,
#  98735583,
#  87347187,
#  98239236,
#  99286472,
#  89664288,
#  87381531,
#  35189141,
#  98829480,
#  99409809,
#  90352269,
#  86441518,
#  85800689,
#  99062586,
#  89123133,
#  96209007,
#  83184586,
#  99236247,
#  1673112,
#  1726452,
#  99016039,
#  99355423,
#  97376573,
#  99423830,
#  99421513,
#  99402032,
#  98479939,
#  95142264,
#  99407085,
#  99407200,
#  99407174,
#  97269833,
#  98731237,
#  98480236,
#  98730783,
#  98416369,
#  97349017,
#  97392390,
#  97223580,
#  97672754,
#  94812997,
#  94816472,
#  94798599,
#  92202705,
#  98693719,
#  98416642,
#  99140236,
#  99140209,
#  99140204,
#  99140224,
#  99140223,
#  93461302,
#  97746122,
#  97746166,
#  97746121,
#  97746135,
#  97560509,
#  98822279,
#  99231918,
#  99398811,
#  98579281,
#  98422378,
#  98422353,
#  98310697,
#  98310694,
#  98310685,
#  93506908,
#  98919629,
#  91015857,
#  90764671,
#  99342596,
#  99139590,
#  98664897,
#  94438466,
#  97269863,
#  95936090,
#  95499925,
#  99227375,
#  98759241,
#  98759217,
#  98759180,
#  98694322,
#  98291831,
#  98281369,
#  98281456,
#  98281434,
#  98281425,
#  94502906,
#  99256604,
#  98489077,
#  99213406,
#  99213375,
#  97226715,
#  97891443,
#  96780350,
#  96780338,
#  94875653,
#  94452791,
#  98257711,
#  97729299,
#  99407752,
#  99280871,
#  99229745,
#  99171035,
#  98348144,
#  99294450,
#  97052160,
#  94212747,
#  99202895,
#  99075078,
#  84427204,
#  99403118,
#  95999629,
#  95340804,
#  99348731,
#  99347775,
#  98766438,
#  98146012,
#  99129348,
#  97909166,
#  97649541,
#  98637502,
#  97007984,
#  98472401,
#  98472579,
#  98472072,
#  99082554,
#  98562999,
#  98386839,
#  98386391,
#  97728293,
#  97118162,
#  97114358,
#  96972808,
#  88474643,
#  90233700,
#  81819874,
#  99005479,
#  98057848,
#  98575757,
#  98478921,
#  87731076,
#  96773115,
#  30872237,
#  98556823,
#  98153962,
#  98087231,
#  98079770,
#  97800234,
#  97504611,
#  96644583,
#  95220322,
#  98767180,
#  96766192,
#  96531515,
#  98511080,
#  36176885,
#  99274064,
#  99260898,
#  98529338,
#  98311807,
#  98157058,
#  97041913,
#  40284020,
#  99239988,
#  98435598,
#  96477259,
#  99205359,
#  98383548,
#  87119220,
#  98458294,
#  98359135,
#  28001162,
#  99165539,
#  98851178,
#  98832409,
#  98658932,
#  98206005,
#  97646059,
#  91657716,
#  87027520,
#  98193852,
#  97784978,
#  97240109,
#  99221218,
#  98326818,
#  96743902,
#  86893358,
#  99160191,
#  99002623,
#  96257663,
#  93507258,
#  98716620,
#  95623415,
#  97753987,
#  98259272,
#  98266632,
#  97256692,
#  95283504,
#  96815353,
#  96800606,
#  95990770,
#  95890214,
#  95330815,
#  93425705,
#  95116125,
#  99097874,
#  99006113,
#  98821144,
#  98241163,
#  97463080,
#  94784137,
#  90019126,
#  34236624,
#  83948683,
#  99004766,
#  97855315,
#  96543714,
#  90218567,
#  98323890,
#  99218966,
#  98478938,
#  98312613,
#  93854794,
#  94964371,
#  99357302,
#  83832838,
#  98581220,
#  99262937,
#  93457620,
#  96792653,
#  98648767,
#  94360163,
#  88563249,
#  99172502,
#  98579053,
#  98238304,
#  93931595,
#  95865870,
#  94211486,
#  99099163,
#  97792702,
#  93466795,
#  99342265,
#  97012860,
#  89296108,
#  98337314,
#  90026358,
#  98595144,
#  98414963,
#  96305785,
#  98790947,
#  96133949,
#  99156554,
#  99216120,
#  98986313,
#  98502872,
#  92113328]

# %%
lista_info_inmuebles = []

for id_inmueble in ids:
    r = request_piso(id_inmueble= id_inmueble, headers=headers)
    soup = bs(r.text, "lxml")
    info_inmueble1 = info_inmueble()
    lista_info_inmuebles.append(info_inmueble1)
    time.sleep(random.randint(1,3)*random.random())

print(id_inmueble)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-40422b8ea474> in <module>
#       4     r = request_piso(id_inmueble= id_inmueble, headers=headers)
#       5     soup = bs(r.text, "lxml")
# ----> 6     info_inmueble1 = info_inmueble()
#       7     lista_info_inmuebles.append(info_inmueble1)
#       8     time.sleep(random.randint(1,3)*random.random())
#
# <ipython-input-10-6f2ede20691d> in info_inmueble()
#       6         if "var config" in str(script):
#       7             break
# ----> 8     latitude = float(str(script).split("latitude")[1].split(",")[0].split()[1].replace("'", ""))
#       9     longitude = float(str(script).split("latitude")[1].split(",")[1].strip().split()[1].replace("'", ""))
#      10
#
# IndexError: list index out of range

# %%
# carretera de cadiz se ha quedado por el 84820967

# %%
# Huelin 116 id, '88341181'

# %%
len(lista_info_inmuebles)
# Out:
# 68

# %%
id_inmueble
# Out:
# '99171035'

# %%
lista_info_inmuebles
# Out:
# [['Chalet adosado en venta en Guadalmar',
#   'Churriana, Málaga',
#   36.6666382,
#   -4.4645759,
#   '395000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '194'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '194',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Poseidón',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6637191,
#   -4.5038972,
#   '640000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '310'},
#   '4',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '310',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Dolores Medio',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6568935,
#   -4.5029302,
#   '567000',
#   'inProcess',
#   {'roomNumber': '5',
#    'bathNumber': '4',
#    'hasParking': '0',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '410'},
#   '5',
#   '4',
#   '1',
#   '1',
#   '0',
#   '1',
#   None,
#   '410',
#   '0',
#   '0',
#   '1'],
#  ['Ático en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '375900',
#   'unknown',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '236'},
#   '4',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '236',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '249900',
#   'unknown',
#   {'roomNumber': '2',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '150'},
#   '2',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '150',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '230900',
#   'unknown',
#   {'roomNumber': '2',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '99'},
#   '2',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '99',
#   '1',
#   '0',
#   '0'],
#  ['Casa o chalet en venta en Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.6510257,
#   -4.4939618,
#   '795000',
#   'c',
#   {'roomNumber': '3',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '702'},
#   '3',
#   '4',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '702',
#   '0',
#   '1',
#   '0'],
#  ['Chalet adosado en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6704273,
#   -4.5071012,
#   '235000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '0',
#    'constructedArea': '149'},
#   '3',
#   '2',
#   '0',
#   '0',
#   '1',
#   '1',
#   None,
#   '149',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.654335,
#   -4.4902179,
#   '690000',
#   'inProcess',
#   {'roomNumber': '5',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '649'},
#   '5',
#   '4',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '649',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6594221,
#   -4.4961917,
#   '371000',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '152'},
#   '3',
#   '3',
#   None,
#   '1',
#   '1',
#   '1',
#   None,
#   '152',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en Urb. PRIVADA CON PISCINA, Guadalmar',
#   'Churriana, Málaga',
#   36.6695382,
#   -4.4631759,
#   '395000',
#   'd',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '152'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '152',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Platero - El Limón',
#   'Alhaurín de la Torre',
#   36.6567909,
#   -4.5700259,
#   '595000',
#   'inProcess',
#   {'roomNumber': '5',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '338'},
#   '5',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '338',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en avenida Ricardo Gross, 5',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.65266,
#   -4.49263,
#   '995000',
#   'a',
#   {'roomNumber': '4',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '265'},
#   '4',
#   '4',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '265',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en avenida María de Orueta, 25',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6523064,
#   -4.4911891,
#   '625000',
#   'd',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasTerrace': '1',
#    'constructedArea': '298'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   None,
#   None,
#   '298',
#   '0',
#   '0',
#   '1'],
#  ['Dúplex en venta en calle Periodista Juan Antonio Rando',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6627194,
#   -4.5008034,
#   '450000',
#   'g',
#   {'roomNumber': '7',
#    'bathNumber': '3',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '133'},
#   '7',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '133',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Josefa Morales, 39',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6712556,
#   -4.5088488,
#   '256500',
#   'd',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasTerrace': '1',
#    'constructedArea': '179'},
#   '3',
#   '1',
#   None,
#   '1',
#   None,
#   None,
#   None,
#   '179',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet en venta en carretera Coín, 108',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6617978,
#   -4.5131005,
#   '422500',
#   'unknown',
#   {'roomNumber': '5',
#    'bathNumber': '3',
#    'hasSwimmingPool': '1',
#    'constructedArea': '257'},
#   '5',
#   '3',
#   None,
#   None,
#   None,
#   '1',
#   None,
#   '257',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en carril LA GAYUMBA, 2',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6522271,
#   -4.4896939,
#   '1399000',
#   'e',
#   {'roomNumber': '8',
#    'bathNumber': '6',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '290'},
#   '8',
#   '6',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '290',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en C. Josefa Morales, 39',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6712556,
#   -4.5088488,
#   '256500',
#   'e',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasTerrace': '1',
#    'constructedArea': '153'},
#   '4',
#   '2',
#   None,
#   '1',
#   None,
#   None,
#   None,
#   '153',
#   '0',
#   '1',
#   '0'],
#  ['Piso en venta en calle Mercedes Formica, 12',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6598242,
#   -4.5041845,
#   '291800',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '116'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '116',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en avenida SAN JAVIER, 65',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6633251,
#   -4.4984817,
#   '235000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '102'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '102',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en C/HESPERIDES, 17',
#   'Guadalmar, Málaga',
#   36.663755,
#   -4.4610281,
#   '262181',
#   'e',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'constructedArea': '103'},
#   '2',
#   '1',
#   None,
#   None,
#   None,
#   None,
#   '1',
#   '103',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Dolores Medio',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6575706,
#   -4.5026624,
#   '567000',
#   'inProcess',
#   {'roomNumber': '5',
#    'bathNumber': '4',
#    'hasParking': '0',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '410'},
#   '5',
#   '4',
#   '1',
#   '1',
#   '0',
#   '1',
#   None,
#   '410',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en avenida Avenida de Velázquez, 56',
#   'La Luz, Málaga',
#   36.6967119,
#   -4.4499633,
#   '273100',
#   'c',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '101'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '101',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en avenida Avenida de Velázquez, 56',
#   'La Luz, Málaga',
#   36.6967119,
#   -4.4499633,
#   '246300',
#   'c',
#   {'roomNumber': '2',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '83'},
#   '2',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '83',
#   '1',
#   '0',
#   '0'],
#  ['Chalet adosado en venta en calle Diario Malagueño, 1',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6686969,
#   -4.5119353,
#   '320000',
#   'unknown',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '160'},
#   '4',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   None,
#   '160',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Torremolinos s/n',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6645609,
#   -4.5046185,
#   '275730',
#   'd',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasGarden': '1',
#    'hasTerrace': '1',
#    'constructedArea': '115'},
#   '3',
#   '2',
#   '1',
#   '1',
#   None,
#   None,
#   None,
#   '115',
#   '0',
#   '0',
#   '1'],
#  ['Chalet pareado en venta en CL CAMPILLOS 2 29120 ALHAURIN EL GRANDE s/n',
#   'Centro, Alhaurín el Grande',
#   36.6412735,
#   -4.6863278,
#   '135000',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasTerrace': '1',
#    'constructedArea': '80'},
#   '3',
#   '1',
#   None,
#   '1',
#   None,
#   None,
#   None,
#   '80',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Reserva, 8',
#   'Pinos de Alhaurín, Alhaurín de la Torre',
#   36.6589208,
#   -4.5786768,
#   '2706000',
#   'f',
#   {'roomNumber': '8',
#    'bathNumber': '8',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '2500'},
#   '8',
#   '8',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '2500',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en avenida Marquesa Casa Loring, 25',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6513777,
#   -4.4926351,
#   '795000',
#   'd',
#   {'roomNumber': '5',
#    'bathNumber': '5',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '407'},
#   '5',
#   '5',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '407',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Isabel Barreto, 15',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6599641,
#   -4.5036408,
#   '1148000',
#   'f',
#   {'roomNumber': '5',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '650'},
#   '5',
#   '4',
#   '1',
#   '1',
#   '1',
#   '0',
#   None,
#   '650',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en avenida Avenida de Velázquez, 56',
#   'La Luz, Málaga',
#   36.6967119,
#   -4.4499633,
#   '436700',
#   'c',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '151'},
#   '4',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '151',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.6595179,
#   -4.5050633,
#   '291800',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '118'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '118',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Figurillas',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6543062,
#   -4.4966166,
#   '790000',
#   'e',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '255'},
#   '4',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '255',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Malasia s/n',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6707764,
#   -4.5164089,
#   '320000',
#   'b',
#   {'roomNumber': '3',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '140'},
#   '3',
#   '3',
#   '0',
#   '1',
#   '1',
#   '1',
#   None,
#   '140',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Av. Asunción',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6536297,
#   -4.4921254,
#   '795000',
#   'a',
#   {'roomNumber': '5',
#    'bathNumber': '5',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '407'},
#   '5',
#   '5',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '407',
#   '0',
#   '1',
#   '0'],
#  ['Piso en venta en calle Mercedes Formica',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6576179,
#   -4.5050633,
#   '297100',
#   'd',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '156'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '156',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en avenida Asunción',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.654368,
#   -4.4935667,
#   '790000',
#   'c',
#   {'roomNumber': '5',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '440'},
#   '5',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '440',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6634024,
#   -4.4985914,
#   '205000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasParking': '1',
#    'hasTerrace': '1',
#    'constructedArea': '130'},
#   '3',
#   '1',
#   None,
#   '1',
#   '1',
#   None,
#   None,
#   '130',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Isabel Barreto, 15',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6599712,
#   -4.503655,
#   '1148000',
#   'f',
#   {'roomNumber': '6',
#    'bathNumber': '6',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasTerrace': '1',
#    'constructedArea': '650'},
#   '6',
#   '6',
#   '1',
#   '1',
#   '1',
#   None,
#   None,
#   '650',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Moby Dick',
#   'Guadalmar, Málaga',
#   36.665484,
#   -4.4593381,
#   '249900',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '83'},
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '83',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Mercedes Formica, 12',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6598242,
#   -4.5041845,
#   '297100',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '118'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '118',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Fresnos de Guadalmar',
#   'Guadalmar, Málaga',
#   36.666543,
#   -4.4609756,
#   '779000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'constructedArea': '230'},
#   '4',
#   '3',
#   '1',
#   None,
#   '1',
#   '1',
#   None,
#   '230',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Ernesto Kusche',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6616864,
#   -4.4983251,
#   '367000',
#   'd',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '195'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '195',
#   '0',
#   '0',
#   '1'],
#  ['Dúplex en venta en REAL DE MÁLAGA',
#   'San Francisco - El Chorrillo, Las Gabias',
#   37.1328,
#   -3.66879,
#   '129900',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasTerrace': '1',
#    'constructedArea': '115'},
#   '4',
#   '2',
#   None,
#   '1',
#   None,
#   None,
#   '1',
#   '115',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en RIBERA',
#   'San Francisco - El Chorrillo, Las Gabias',
#   37.1329055,
#   -3.6706027,
#   '179999',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '230'},
#   '4',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '230',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.6469253,
#   -4.5018207,
#   '182100',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasParking': '0',
#    'hasTerrace': '1',
#    'constructedArea': '83'},
#   '3',
#   '1',
#   None,
#   '1',
#   '0',
#   None,
#   None,
#   '83',
#   '0',
#   '1',
#   '0'],
#  ['Piso en venta en calle Rogelio Oliva, 11',
#   'Guadalmar, Málaga',
#   36.6638777,
#   -4.4607722,
#   '262181',
#   'f',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '0',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'constructedArea': '108'},
#   '2',
#   '1',
#   '1',
#   None,
#   '0',
#   '1',
#   '1',
#   '108',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.6507172,
#   -4.4980983,
#   '900000',
#   'inProcess',
#   {'roomNumber': '6',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '384'},
#   '6',
#   '4',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '384',
#   '0',
#   '1',
#   '0'],
#  ['Piso en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6659889,
#   -4.5149367,
#   '182000',
#   'inProcess',
#   {'roomNumber': '1',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '55'},
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '55',
#   '0',
#   '0',
#   '1'],
#  ['Finca rústica en venta en Pinos de Alhaurín',
#   'Alhaurín de la Torre',
#   36.6597396,
#   -4.5822228,
#   '210000',
#   'inProcess',
#   {'roomNumber': '1',
#    'bathNumber': '1',
#    'hasParking': '0',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'constructedArea': '65'},
#   '1',
#   '1',
#   '1',
#   None,
#   '0',
#   '1',
#   None,
#   '65',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.660146,
#   -4.4978386,
#   '235000',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'constructedArea': '89'},
#   '3',
#   '2',
#   '1',
#   None,
#   '1',
#   '1',
#   '1',
#   '89',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en avenida Ricardo Gross',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6548086,
#   -4.4900614,
#   '790000',
#   'd',
#   {'roomNumber': '5',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '440'},
#   '5',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '440',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en avenida Ricardo Gross',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.653835,
#   -4.4919179,
#   '790000',
#   'g',
#   {'roomNumber': '5',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '360'},
#   '5',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '360',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6633891,
#   -4.4988999,
#   '299990',
#   'e',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '0',
#    'constructedArea': '213'},
#   '4',
#   '3',
#   '0',
#   '0',
#   '1',
#   '0',
#   None,
#   '213',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6613088,
#   -4.4990457,
#   '250000',
#   'f',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '109'},
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '109',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6695723,
#   -4.5186574,
#   '320000',
#   'a',
#   {'roomNumber': '3',
#    'bathNumber': '3',
#    'hasParking': '0',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '161'},
#   '3',
#   '3',
#   '0',
#   '1',
#   '0',
#   '1',
#   None,
#   '161',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en antequera',
#   'Pinos de Alhaurín, Alhaurín de la Torre',
#   36.6450558,
#   -4.5901766,
#   '550000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '280'},
#   '4',
#   '4',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '280',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en CORTIJO MAZA',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6463857,
#   -4.5002249,
#   '639000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '298'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '0',
#   None,
#   '298',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Angola s/n',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6632566,
#   -4.5192925,
#   '330000',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '239'},
#   '3',
#   '4',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '239',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Acacias de Guadalmar',
#   'Guadalmar, Málaga',
#   36.6675775,
#   -4.4623495,
#   '1500000',
#   'd',
#   {'roomNumber': '5',
#    'bathNumber': '6',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '600'},
#   '5',
#   '6',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '600',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en avenida ANDALUCIA',
#   'San Francisco - El Chorrillo, Las Gabias',
#   37.1311247,
#   -3.6723631,
#   '54900',
#   'inProcess',
#   {'roomNumber': '1',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '1',
#    'constructedArea': '53'},
#   '1',
#   '1',
#   None,
#   None,
#   '1',
#   None,
#   '1',
#   '53',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en carril de Mestanza, 50',
#   'El Romeral-Peñón de Zapata, Alhaurín de la Torre',
#   36.6955102,
#   -4.5546675,
#   '425000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '230'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '230',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6656448,
#   -4.472338,
#   '410000',
#   'e',
#   {'roomNumber': '8',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '210'},
#   '8',
#   '4',
#   '1',
#   '1',
#   '1',
#   '0',
#   None,
#   '210',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.6495488,
#   -4.4888463,
#   '895000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '500'},
#   '4',
#   '4',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '500',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en avenida de Velázquez',
#   'Los Guindos - Parque Mediterráneo - Santa Paula, Málaga',
#   36.6988581,
#   -4.4476889,
#   '249900',
#   'unknown',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '0',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '80'},
#   '2',
#   '1',
#   '0',
#   '1',
#   '0',
#   '0',
#   '1',
#   '80',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en avenida de San Javier',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6648899,
#   -4.4972496,
#   '249000',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '0',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '106'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '0',
#   '1',
#   '1',
#   '106',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6652929,
#   -4.4998666,
#   '223000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '102'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '102',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6723596,
#   -4.5069099,
#   '235000',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '120'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '120',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Alberto Peláez Domínguez, 16',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6656226,
#   -4.4995242,
#   '298000',
#   'e',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '231'},
#   '4',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   None,
#   '231',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en La Luz',
#   'Carretera de Cádiz, Málaga',
#   36.69337,
#   -4.45395,
#   '139900',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '0',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '0',
#    'constructedArea': '76'},
#   '3',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '1',
#   '76',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Portales del Popo',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6722374,
#   -4.5054086,
#   '172000',
#   'unknown',
#   {'roomNumber': '2',
#    'bathNumber': '2',
#    'hasTerrace': '1',
#    'constructedArea': '86'},
#   '2',
#   '2',
#   None,
#   '1',
#   None,
#   None,
#   None,
#   '86',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6638147,
#   -4.5058824,
#   '5000000',
#   'c',
#   {'roomNumber': '11',
#    'bathNumber': '6',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '1600'},
#   '11',
#   '6',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '1600',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en avenida de velazquez',
#   'Girón - Las Delicias - Pacífico, Málaga',
#   36.6983376,
#   -4.4455878,
#   '180000',
#   'inProcess',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'constructedArea': '75'},
#   '2',
#   '1',
#   None,
#   None,
#   None,
#   None,
#   '1',
#   '75',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Acacias de Guadalmar',
#   'Guadalmar, Málaga',
#   36.6674775,
#   -4.4605495,
#   '1500000',
#   'c',
#   {'roomNumber': '4',
#    'bathNumber': '5',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '620'},
#   '4',
#   '5',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '620',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.672398,
#   -4.5068266,
#   '318500',
#   'g',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '180'},
#   '4',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '180',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en avenida de Velázquez',
#   'Girón - Las Delicias - Pacífico, Málaga',
#   36.6991275,
#   -4.4459164,
#   '160000',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'constructedArea': '80'},
#   '3',
#   '1',
#   None,
#   None,
#   None,
#   None,
#   '1',
#   '80',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle del Escritor Béjar Zambrana',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6594796,
#   -4.4953536,
#   '370000',
#   'c',
#   {'roomNumber': '3',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '198'},
#   '3',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '198',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Maestro Vicente Lleó, 10',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6643215,
#   -4.5000073,
#   '205000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '67'},
#   '3',
#   '1',
#   '0',
#   '1',
#   '1',
#   '0',
#   None,
#   '67',
#   '0',
#   '1',
#   '0'],
#  ['Ático en venta en calle Tanzania, 3',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6620559,
#   -4.5186553,
#   '350000',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '123'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '123',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en camino de la Sierra, 64',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.654312,
#   -4.5117104,
#   '640000',
#   'unknown',
#   {'roomNumber': '4',
#    'bathNumber': '5',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '300'},
#   '4',
#   '5',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '300',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Heliomar',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6607864,
#   -4.503071,
#   '157500',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '0',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '68'},
#   '3',
#   '1',
#   '1',
#   '1',
#   '0',
#   '1',
#   '1',
#   '68',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en camino Agropecuario de Realenga',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6524475,
#   -4.490088,
#   '725000',
#   'inProcess',
#   {'roomNumber': '5',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasTerrace': '1',
#    'constructedArea': '278'},
#   '5',
#   '3',
#   '1',
#   '1',
#   '1',
#   None,
#   None,
#   '278',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6626183,
#   -4.5026068,
#   '299000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '150'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '0',
#   None,
#   '150',
#   '0',
#   '0',
#   '1'],
#  ['Ático en venta en calle Acacias de Guadalmar',
#   'Guadalmar, Málaga',
#   36.6631287,
#   -4.4561357,
#   '430000',
#   'a',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasTerrace': '1',
#    'constructedArea': '160'},
#   '3',
#   '2',
#   None,
#   '1',
#   '1',
#   None,
#   '1',
#   '160',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en La Luz',
#   'Carretera de Cádiz, Málaga',
#   36.6972921,
#   -4.4511214,
#   '162000',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '0',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '74'},
#   '3',
#   '1',
#   '0',
#   '1',
#   '0',
#   '0',
#   '1',
#   '74',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en pasaje Mari-Gaila, 8',
#   'Guadalmar, Málaga',
#   36.6676778,
#   -4.4653004,
#   '395000',
#   'unknown',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '194'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '194',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en carretera Coín, 29',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.659266,
#   -4.4937989,
#   '860000',
#   'unknown',
#   {'roomNumber': '5',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '223'},
#   '5',
#   '2',
#   '1',
#   '1',
#   '1',
#   '0',
#   None,
#   '223',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle del Escritor Béjar Zambrana',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6618741,
#   -4.495526,
#   '360000',
#   'c',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '220'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '220',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Guadalmar',
#   'Churriana, Málaga',
#   36.6645775,
#   -4.4600495,
#   '1500000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '6',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '630'},
#   '4',
#   '6',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '630',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.652233,
#   -4.49582,
#   '639000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '298'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '0',
#   None,
#   '298',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Urb. Guadalmar, Guadalmar',
#   'Churriana, Málaga',
#   36.665476,
#   -4.461655,
#   '1500000',
#   'c',
#   {'roomNumber': '4',
#    'bathNumber': '6',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '710'},
#   '4',
#   '6',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '710',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Urb. churriana centro, Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6653113,
#   -4.5052488,
#   '173000',
#   'unknown',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasParking': '0',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '91'},
#   '2',
#   '1',
#   '0',
#   '1',
#   '0',
#   '0',
#   None,
#   '91',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6604195,
#   -4.5190936,
#   '640000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '250'},
#   '4',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '250',
#   '0',
#   '0',
#   '1'],
#  ['Dúplex en venta en calle Merlo, 27',
#   'Cruz del Humilladero - Los Tilos, Málaga',
#   36.7143969,
#   -4.4393075,
#   '340000',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '76'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '0',
#   '1',
#   '76',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Malasia, 37',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67104,
#   -4.5181699,
#   '359000',
#   'c',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '190'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '0',
#   None,
#   '190',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Cañada de Ceuta s/n',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6470284,
#   -4.5082433,
#   '700000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '455'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '455',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle del Escritor Béjar Zambrana, 3',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6611221,
#   -4.4958917,
#   '360000',
#   'a',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '220'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '220',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en avenida Asunción, 3',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6538028,
#   -4.4930439,
#   '700000',
#   'unknown',
#   {'roomNumber': '5',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '270'},
#   '5',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '270',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Árbol Blanco, 55',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.667023,
#   -4.5010688,
#   '255000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '178'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '0',
#   None,
#   '178',
#   '0',
#   '1',
#   '0'],
#  ['Chalet pareado en venta en Urb. adelfamar , Churriana-El Pizarrillo-La Noria-Guadalsol',
#   'Churriana, Málaga',
#   36.6713789,
#   -4.5070138,
#   '310000',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '251'},
#   '3',
#   '3',
#   '0',
#   '1',
#   '1',
#   '0',
#   None,
#   '251',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en avenida de San Javier, 67',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6633929,
#   -4.4986666,
#   '240000',
#   'g',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '109'},
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '109',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Avempace, 10',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6485811,
#   -4.5021544,
#   '270000',
#   'a',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '100'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '100',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Heliomar, 1',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.661246,
#   -4.5010769,
#   '190000',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '0',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '77'},
#   '3',
#   '1',
#   '1',
#   '1',
#   '0',
#   '1',
#   '1',
#   '77',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Urb. El Olivar, Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.6509694,
#   -4.4934611,
#   '1975000',
#   'd',
#   {'roomNumber': '5',
#    'bathNumber': '7',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '706'},
#   '5',
#   '7',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '706',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en Urb. PRIVADA, La Luz',
#   'Carretera de Cádiz, Málaga',
#   36.6939299,
#   -4.4588624,
#   '260000',
#   'd',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'constructedArea': '114'},
#   '3',
#   '1',
#   '1',
#   None,
#   '1',
#   None,
#   '1',
#   '114',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Decano Joaquín Wuester, 3',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6658835,
#   -4.4731468,
#   '215000',
#   'f',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '85'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '0',
#   '1',
#   '85',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Diputado Ignacio Huelin',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6520052,
#   -4.4983126,
#   '449900',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '0',
#    'hasGarden': '0',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '0',
#    'constructedArea': '250'},
#   '4',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   None,
#   '250',
#   '0',
#   '0',
#   '1'],
#  ['Chalet pareado en venta en CL ESTACIÓN, 20',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6678521,
#   -4.5026877,
#   '85000',
#   'inProcess',
#   {'roomNumber': '2', 'bathNumber': '1', 'constructedArea': '55'},
#   '2',
#   '1',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '55',
#   '0',
#   '1',
#   '0'],
#  ['Chalet adosado en venta en calle ALBERTO PELÁEZ DOMÍNGUEZ',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6674941,
#   -4.4980792,
#   '298000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasSwimmingPool': '1',
#    'constructedArea': '231'},
#   '4',
#   '2',
#   None,
#   None,
#   '1',
#   '1',
#   None,
#   '231',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Mercedes Formica, 12',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6598242,
#   -4.5041845,
#   '291800',
#   'g',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '159'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '159',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Hespérides s/n',
#   'Guadalmar, Málaga',
#   36.6634751,
#   -4.4611374,
#   '262181',
#   'e',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '102'},
#   '2',
#   '1',
#   '1',
#   '1',
#   None,
#   '1',
#   '1',
#   '102',
#   '0',
#   '0',
#   '1'],
#  ['Ático en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '255900',
#   'unknown',
#   {'roomNumber': '2',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '149'},
#   '2',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '149',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '265900',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '119'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '119',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '255900',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '165'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '165',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '265900',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '113'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '113',
#   '1',
#   '0',
#   '0'],
#  ['Chalet adosado en venta en calle Avempace, 10',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6487253,
#   -4.5018207,
#   '182100',
#   'g',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasTerrace': '1',
#    'constructedArea': '83'},
#   '2',
#   '1',
#   None,
#   '1',
#   None,
#   None,
#   None,
#   '83',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Mercedes Formica, 12',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6598242,
#   -4.5041845,
#   '291800',
#   'g',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '159'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '159',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Avempace',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6499253,
#   -4.5013207,
#   '182100',
#   'g',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasGarden': '1',
#    'hasTerrace': '1',
#    'constructedArea': '83'},
#   '2',
#   '1',
#   '1',
#   '1',
#   None,
#   None,
#   None,
#   '83',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Josefa Morales',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6692556,
#   -4.5108488,
#   '256500',
#   'g',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasTerrace': '1',
#    'constructedArea': '153'},
#   '4',
#   '2',
#   None,
#   '1',
#   None,
#   None,
#   None,
#   '153',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Isabel Barreto',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6591767,
#   -4.502023,
#   '1148000',
#   'g',
#   {'roomNumber': '6',
#    'bathNumber': '6',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasTerrace': '1',
#    'constructedArea': '650'},
#   '6',
#   '6',
#   '1',
#   '1',
#   '1',
#   None,
#   None,
#   '650',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en avenida Ricardo Gross, 12',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6530063,
#   -4.4933191,
#   '750000',
#   'd',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '551'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '551',
#   '0',
#   '0',
#   '1'],
# ...
#   36.6657797,
#   -4.5058803,
#   '344000',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '105'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '105',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle La Gioconda, 32',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6657797,
#   -4.5058803,
#   '318000',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '0',
#    'constructedArea': '104'},
#   '3',
#   '2',
#   '1',
#   '0',
#   '1',
#   '1',
#   '1',
#   '104',
#   '1',
#   '0',
#   '0'],
#  ['Casa o chalet independiente en venta en avenida Marquesa Casa Loring, 7',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6508438,
#   -4.4906787,
#   '790000',
#   'e',
#   {'roomNumber': '5',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '552'},
#   '5',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '552',
#   '0',
#   '1',
#   '0'],
#  ['Piso en venta en calle Miami, 7',
#   'La Carihuela - Los Nidos, Torremolinos',
#   36.6107298,
#   -4.5038413,
#   '175000',
#   'a',
#   {'roomNumber': '1',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '50'},
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '50',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Urb. EL OLIVAR, Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.6549146,
#   -4.4916536,
#   '1990000',
#   'c',
#   {'roomNumber': '11',
#    'bathNumber': '7',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '1028'},
#   '11',
#   '7',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '1028',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en Urb. El Olivar, Cortijo de Maza-Finca Monsalvez-El Olivar',
#   'Churriana, Málaga',
#   36.6563299,
#   -4.4900142,
#   '1210000',
#   'd',
#   {'roomNumber': '5',
#    'bathNumber': '5',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '659'},
#   '5',
#   '5',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '659',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Nepal',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6689494,
#   -4.5176987,
#   '334000',
#   'c',
#   {'roomNumber': '2',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '143'},
#   '2',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '143',
#   '0',
#   '0',
#   '1'],
#  ['Chalet pareado en venta en calle Diputado Ignacio Huelin',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6546359,
#   -4.4973702,
#   '445000',
#   'd',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasTerrace': '1',
#    'constructedArea': '300'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   None,
#   None,
#   '300',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Decano Juan Antonio Rando',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.668864,
#   -4.4762231,
#   '215000',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasParking': '1',
#    'constructedArea': '171'},
#   '3',
#   '1',
#   None,
#   None,
#   '1',
#   None,
#   None,
#   '171',
#   '0',
#   '0',
#   '1'],
#  ['Ático en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '375900',
#   'unknown',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '236'},
#   '4',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '236',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '279900',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '118'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '118',
#   '1',
#   '0',
#   '0'],
#  ['Chalet adosado en venta en calle Indonesia , 39',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6719099,
#   -4.51791,
#   '299900',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '0',
#    'constructedArea': '139'},
#   '3',
#   '3',
#   '1',
#   '0',
#   '1',
#   '1',
#   None,
#   '139',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Bangladesh, 25',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.67119,
#   -4.5169,
#   '249900',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '117'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '117',
#   '1',
#   '0',
#   '0'],
#  ['Ático en venta en calle Madre Asunción Soler s/n',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.660194,
#   -4.49976,
#   '385000',
#   'b',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '116'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '116',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Churriana de la vega esqueino calle malaga, 1',
#   'Zona de San Cayetano, Churriana de la Vega',
#   37.1450549,
#   -3.6416323,
#   '172670',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '125'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '125',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Churriana de la vega esqueino calle malaga, 1',
#   'Zona de San Cayetano, Churriana de la Vega',
#   37.1450549,
#   -3.6416323,
#   '165877',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '111'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '111',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Churriana de la vega esqueino calle malaga, 1',
#   'Zona de San Cayetano, Churriana de la Vega',
#   37.1450549,
#   -3.6416323,
#   '170297',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '112'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '112',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Hespérides',
#   'Guadalmar, Málaga',
#   36.6620393,
#   -4.460432,
#   '262181',
#   'f',
#   {'roomNumber': '2',
#    'bathNumber': '1',
#    'hasLift': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'constructedArea': '102'},
#   '2',
#   '1',
#   '1',
#   None,
#   None,
#   '1',
#   '1',
#   '102',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Churriana de la vega esqueino calle malaga, 1',
#   'Zona de San Cayetano, Churriana de la Vega',
#   37.1450549,
#   -3.6416323,
#   '159320',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '0',
#    'constructedArea': '119'},
#   '3',
#   '2',
#   '1',
#   '0',
#   '1',
#   '1',
#   '1',
#   '119',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Churriana de la vega esqueino calle malaga, 1',
#   'Zona de San Cayetano, Churriana de la Vega',
#   37.1450549,
#   -3.6416323,
#   '165787',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '0',
#    'constructedArea': '125'},
#   '3',
#   '2',
#   '1',
#   '0',
#   '1',
#   '1',
#   '1',
#   '125',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Churriana de la vega esqueino calle malaga, 1',
#   'Zona de San Cayetano, Churriana de la Vega',
#   37.1450549,
#   -3.6416323,
#   '176746',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '0',
#    'constructedArea': '116'},
#   '3',
#   '2',
#   '1',
#   '0',
#   '1',
#   '1',
#   '1',
#   '116',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Churriana de la vega esqueino calle malaga, 1',
#   'Zona de San Cayetano, Churriana de la Vega',
#   37.1450549,
#   -3.6416323,
#   '188400',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '130'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '130',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Churriana de la vega esqueino calle malaga, 1',
#   'Zona de San Cayetano, Churriana de la Vega',
#   37.1450549,
#   -3.6416323,
#   '175599',
#   'unknown',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '118'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '118',
#   '1',
#   '0',
#   '0'],
#  ['Casa o chalet independiente en venta en calle Dinamarca',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6457453,
#   -4.5016944,
#   '1800000',
#   'd',
#   {'roomNumber': '5',
#    'bathNumber': '5',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '1004'},
#   '5',
#   '5',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '1004',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en carretera de Coin, 108',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6617978,
#   -4.5131005,
#   '422500',
#   'e',
#   {'roomNumber': '6',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '296'},
#   '6',
#   '4',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '296',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en avenida Marquesa Casa Loring',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6532991,
#   -4.48858,
#   '799900',
#   'd',
#   {'roomNumber': '6',
#    'bathNumber': '4',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '380'},
#   '6',
#   '4',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '380',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Mercedes Formica',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.661331,
#   -4.5033686,
#   '291800',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '118'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '118',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Mercedes Formica',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.659031,
#   -4.5043686,
#   '297100',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '116'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '116',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Manuel Curros Enríquez',
#   'Guadalmar, Málaga',
#   36.6667599,
#   -4.4617824,
#   '698000',
#   'e',
#   {'roomNumber': '6',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '351'},
#   '6',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '351',
#   '0',
#   '0',
#   '1'],
#  ['Piso en venta en calle Madre Asunción Soler s/n',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.660194,
#   -4.49976,
#   '315000',
#   'b',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '109'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '109',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Madre Asunción Soler s/n',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.660194,
#   -4.49976,
#   '278000',
#   'b',
#   {'roomNumber': '2',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '94'},
#   '2',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '94',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Madre Asunción Soler s/n',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.660194,
#   -4.49976,
#   '319000',
#   'b',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '0',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '109'},
#   '3',
#   '2',
#   '0',
#   '1',
#   '1',
#   '1',
#   '1',
#   '109',
#   '1',
#   '0',
#   '0'],
#  ['Piso en venta en calle Mercedes Formica, 12',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6598242,
#   -4.5041845,
#   '291800',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '1',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '118'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '1',
#   '118',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Josefa Morales, 39',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6712418,
#   -4.5089442,
#   '256500',
#   'e',
#   {'roomNumber': '3',
#    'bathNumber': '1',
#    'hasParking': '0',
#    'hasTerrace': '1',
#    'constructedArea': '179'},
#   '3',
#   '1',
#   None,
#   '1',
#   '0',
#   None,
#   None,
#   '179',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Malasia',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6698723,
#   -4.5194574,
#   '320000',
#   'b',
#   {'roomNumber': '3',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '140'},
#   '3',
#   '3',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '140',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle Isabel Barreto',
#   'Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga',
#   36.6617583,
#   -4.5044688,
#   '595000',
#   'e',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '0',
#    'hasTerrace': '1',
#    'constructedArea': '226'},
#   '4',
#   '3',
#   '1',
#   '1',
#   '1',
#   '0',
#   None,
#   '226',
#   '0',
#   '0',
#   '1'],
#  ['Casa o chalet independiente en venta en calle Uganda, 45',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6646899,
#   -4.5194822,
#   '640000',
#   'unknown',
#   {'roomNumber': '4',
#    'bathNumber': '2',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '310'},
#   '4',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   None,
#   '310',
#   '0',
#   '0',
#   '1'],
#  ['Dúplex en venta en calle Tanzania',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6611372,
#   -4.5199706,
#   '367500',
#   'inProcess',
#   {'roomNumber': '3',
#    'bathNumber': '2',
#    'hasLift': '0',
#    'hasParking': '1',
#    'hasGarden': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '123'},
#   '3',
#   '2',
#   '1',
#   '1',
#   '1',
#   '1',
#   '0',
#   '123',
#   '0',
#   '0',
#   '1'],
#  ['Chalet adosado en venta en calle ESCRITOR BÉJAR ZAMBRANA',
#   'Churriana-El Pizarrillo-La Noria-Guadalsol, Málaga',
#   36.6625221,
#   -4.4978917,
#   '360000',
#   'inProcess',
#   {'roomNumber': '4',
#    'bathNumber': '3',
#    'hasParking': '1',
#    'hasSwimmingPool': '1',
#    'hasTerrace': '1',
#    'constructedArea': '202'},
#   '4',
#   '3',
#   None,
#   '1',
#   '1',
#   '1',
#   None,
#   '202',
#   '0',
#   '0',
#   '1']]

# %%
columns = ["titulo", "localizacion", "latitude", "longitude", "price", "energy_certification", "basic_characteristics",
            "room_number", "bath_number", "has_garden", "has_terrace", "has_parking", "has_swimmingpool", "has_lift", "constructed_area",
            "is_new_development", "is_needs_renovating", "is_goog_condition"]

# %%
df_inmuebles = pd.DataFrame(lista_info_inmuebles, columns= columns)

# %%
df_inmuebles
# Out:
#                                                 titulo  \
# 0                 Chalet adosado en venta en Guadalmar
# 1    Casa o chalet independiente en venta en calle ...
# 2    Casa o chalet independiente en venta en calle ...
# 3               Ático en venta en calle Bangladesh, 25
# 4                Piso en venta en calle Bangladesh, 25
# 5                Piso en venta en calle Bangladesh, 25
# 6    Casa o chalet en venta en Cortijo de Maza-Finc...
# 7    Chalet adosado en venta en Churriana-El Pizarr...
# 8    Casa o chalet independiente en venta en Cortij...
# 9    Chalet adosado en venta en Churriana-El Pizarr...
# 10   Chalet adosado en venta en Urb. PRIVADA CON PI...
# 11   Casa o chalet independiente en venta en Plater...
# 12   Casa o chalet independiente en venta en avenid...
# 13   Casa o chalet independiente en venta en avenid...
# 14   Dúplex en venta en calle Periodista Juan Anton...
# 15   Chalet adosado en venta en calle Josefa Morale...
# 16       Casa o chalet en venta en carretera Coín, 108
# 17   Casa o chalet independiente en venta en carril...
# 18    Chalet adosado en venta en C. Josefa Morales, 39
# 19         Piso en venta en calle Mercedes Formica, 12
# 20             Piso en venta en avenida SAN JAVIER, 65
# 21                   Piso en venta en C/HESPERIDES, 17
# 22   Casa o chalet independiente en venta en calle ...
# 23   Piso en venta en avenida Avenida de Velázquez, 56
# 24   Piso en venta en avenida Avenida de Velázquez, 56
# 25   Chalet adosado en venta en calle Diario Malagu...
# 26   Chalet adosado en venta en calle Torremolinos s/n
# 27   Chalet pareado en venta en CL CAMPILLOS 2 2912...
# 28   Casa o chalet independiente en venta en calle ...
# 29   Casa o chalet independiente en venta en avenid...
# ..                                                 ...
# 157             Ático en venta en calle Bangladesh, 25
# 158              Piso en venta en calle Bangladesh, 25
# 159    Chalet adosado en venta en calle Indonesia , 39
# 160              Piso en venta en calle Bangladesh, 25
# 161   Ático en venta en calle Madre Asunción Soler s/n
# 162  Piso en venta en calle Churriana de la vega es...
# 163  Piso en venta en calle Churriana de la vega es...
# 164  Piso en venta en calle Churriana de la vega es...
# 165                  Piso en venta en calle Hespérides
# 166  Piso en venta en calle Churriana de la vega es...
# 167  Piso en venta en calle Churriana de la vega es...
# 168  Piso en venta en calle Churriana de la vega es...
# 169  Piso en venta en calle Churriana de la vega es...
# 170  Piso en venta en calle Churriana de la vega es...
# 171  Casa o chalet independiente en venta en calle ...
# 172  Casa o chalet independiente en venta en carret...
# 173  Casa o chalet independiente en venta en avenid...
# 174            Piso en venta en calle Mercedes Formica
# 175            Piso en venta en calle Mercedes Formica
# 176  Casa o chalet independiente en venta en calle ...
# 177    Piso en venta en calle Madre Asunción Soler s/n
# 178    Piso en venta en calle Madre Asunción Soler s/n
# 179    Piso en venta en calle Madre Asunción Soler s/n
# 180        Piso en venta en calle Mercedes Formica, 12
# 181  Chalet adosado en venta en calle Josefa Morale...
# 182           Chalet adosado en venta en calle Malasia
# 183    Chalet adosado en venta en calle Isabel Barreto
# 184  Casa o chalet independiente en venta en calle ...
# 185                  Dúplex en venta en calle Tanzania
# 186  Chalet adosado en venta en calle ESCRITOR BÉJA...
#
#                                           localizacion   latitude  longitude  \
# 0                                    Churriana, Málaga  36.666638  -4.464576
# 1    Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.663719  -4.503897
# 2    Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.656894  -4.502930
# 3    Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671190  -4.516900
# 4    Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671190  -4.516900
# 5    Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671190  -4.516900
# 6                                    Churriana, Málaga  36.651026  -4.493962
# 7                                    Churriana, Málaga  36.670427  -4.507101
# 8                                    Churriana, Málaga  36.654335  -4.490218
# 9                                    Churriana, Málaga  36.659422  -4.496192
# 10                                   Churriana, Málaga  36.669538  -4.463176
# 11                                Alhaurín de la Torre  36.656791  -4.570026
# 12   Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.652660  -4.492630
# 13   Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.652306  -4.491189
# 14   Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.662719  -4.500803
# 15   Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671256  -4.508849
# 16   Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.661798  -4.513101
# 17   Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.652227  -4.489694
# 18   Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671256  -4.508849
# 19   Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.659824  -4.504185
# 20   Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.663325  -4.498482
# 21                                   Guadalmar, Málaga  36.663755  -4.461028
# 22   Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.657571  -4.502662
# 23                                      La Luz, Málaga  36.696712  -4.449963
# 24                                      La Luz, Málaga  36.696712  -4.449963
# 25   Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.668697  -4.511935
# 26   Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.664561  -4.504619
# 27                          Centro, Alhaurín el Grande  36.641273  -4.686328
# 28             Pinos de Alhaurín, Alhaurín de la Torre  36.658921  -4.578677
# 29   Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.651378  -4.492635
# ..                                                 ...        ...        ...
# 157  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671190  -4.516900
# 158  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671190  -4.516900
# 159  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671910  -4.517910
# 160  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671190  -4.516900
# 161  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.660194  -4.499760
# 162         Zona de San Cayetano, Churriana de la Vega  37.145055  -3.641632
# 163         Zona de San Cayetano, Churriana de la Vega  37.145055  -3.641632
# 164         Zona de San Cayetano, Churriana de la Vega  37.145055  -3.641632
# 165                                  Guadalmar, Málaga  36.662039  -4.460432
# 166         Zona de San Cayetano, Churriana de la Vega  37.145055  -3.641632
# 167         Zona de San Cayetano, Churriana de la Vega  37.145055  -3.641632
# 168         Zona de San Cayetano, Churriana de la Vega  37.145055  -3.641632
# 169         Zona de San Cayetano, Churriana de la Vega  37.145055  -3.641632
# 170         Zona de San Cayetano, Churriana de la Vega  37.145055  -3.641632
# 171  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.645745  -4.501694
# 172  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.661798  -4.513101
# 173  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.653299  -4.488580
# 174  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.661331  -4.503369
# 175  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.659031  -4.504369
# 176                                  Guadalmar, Málaga  36.666760  -4.461782
# 177  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.660194  -4.499760
# 178  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.660194  -4.499760
# 179  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.660194  -4.499760
# 180  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.659824  -4.504185
# 181  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.671242  -4.508944
# 182  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.669872  -4.519457
# 183  Cortijo de Maza-Finca Monsalvez-El Olivar, Málaga  36.661758  -4.504469
# 184  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.664690  -4.519482
# 185  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.661137  -4.519971
# 186  Churriana-El Pizarrillo-La Noria-Guadalsol, Má...  36.662522  -4.497892
#
#        price energy_certification  \
# 0     395000            inProcess
# 1     640000            inProcess
# 2     567000            inProcess
# 3     375900              unknown
# 4     249900              unknown
# 5     230900              unknown
# 6     795000                    c
# 7     235000                    e
# 8     690000            inProcess
# 9     371000            inProcess
# 10    395000                    d
# 11    595000            inProcess
# 12    995000                    a
# 13    625000                    d
# 14    450000                    g
# 15    256500                    d
# 16    422500              unknown
# 17   1399000                    e
# 18    256500                    e
# 19    291800                    e
# 20    235000                    e
# 21    262181                    e
# 22    567000            inProcess
# 23    273100                    c
# 24    246300                    c
# 25    320000              unknown
# 26    275730                    d
# 27    135000            inProcess
# 28   2706000                    f
# 29    795000                    d
# ..       ...                  ...
# 157   375900              unknown
# 158   279900              unknown
# 159   299900              unknown
# 160   249900              unknown
# 161   385000                    b
# 162   172670              unknown
# 163   165877              unknown
# 164   170297              unknown
# 165   262181                    f
# 166   159320              unknown
# 167   165787              unknown
# 168   176746              unknown
# 169   188400              unknown
# 170   175599              unknown
# 171  1800000                    d
# 172   422500                    e
# 173   799900                    d
# 174   291800            inProcess
# 175   297100            inProcess
# 176   698000                    e
# 177   315000                    b
# 178   278000                    b
# 179   319000                    b
# 180   291800                    e
# 181   256500                    e
# 182   320000                    b
# 183   595000                    e
# 184   640000              unknown
# 185   367500            inProcess
# 186   360000            inProcess
#
#                                  basic_characteristics room_number  \
# 0    {'roomNumber': '4', 'bathNumber': '3', 'hasPar...           4
# 1    {'roomNumber': '4', 'bathNumber': '2', 'hasPar...           4
# 2    {'roomNumber': '5', 'bathNumber': '4', 'hasPar...           5
# 3    {'roomNumber': '4', 'bathNumber': '2', 'hasLif...           4
# 4    {'roomNumber': '2', 'bathNumber': '2', 'hasLif...           2
# 5    {'roomNumber': '2', 'bathNumber': '2', 'hasLif...           2
# 6    {'roomNumber': '3', 'bathNumber': '4', 'hasPar...           3
# 7    {'roomNumber': '3', 'bathNumber': '2', 'hasPar...           3
# 8    {'roomNumber': '5', 'bathNumber': '4', 'hasPar...           5
# 9    {'roomNumber': '3', 'bathNumber': '3', 'hasPar...           3
# 10   {'roomNumber': '4', 'bathNumber': '3', 'hasPar...           4
# 11   {'roomNumber': '5', 'bathNumber': '3', 'hasPar...           5
# 12   {'roomNumber': '4', 'bathNumber': '4', 'hasPar...           4
# 13   {'roomNumber': '4', 'bathNumber': '3', 'hasPar...           4
# 14   {'roomNumber': '7', 'bathNumber': '3', 'hasLif...           7
# 15   {'roomNumber': '3', 'bathNumber': '1', 'hasTer...           3
# 16   {'roomNumber': '5', 'bathNumber': '3', 'hasSwi...           5
# 17   {'roomNumber': '8', 'bathNumber': '6', 'hasPar...           8
# 18   {'roomNumber': '4', 'bathNumber': '2', 'hasTer...           4
# 19   {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 20   {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 21   {'roomNumber': '2', 'bathNumber': '1', 'hasLif...           2
# 22   {'roomNumber': '5', 'bathNumber': '4', 'hasPar...           5
# 23   {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 24   {'roomNumber': '2', 'bathNumber': '2', 'hasLif...           2
# 25   {'roomNumber': '4', 'bathNumber': '2', 'hasPar...           4
# 26   {'roomNumber': '3', 'bathNumber': '2', 'hasGar...           3
# 27   {'roomNumber': '3', 'bathNumber': '1', 'hasTer...           3
# 28   {'roomNumber': '8', 'bathNumber': '8', 'hasPar...           8
# 29   {'roomNumber': '5', 'bathNumber': '5', 'hasPar...           5
# ..                                                 ...         ...
# 157  {'roomNumber': '4', 'bathNumber': '2', 'hasLif...           4
# 158  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 159  {'roomNumber': '3', 'bathNumber': '3', 'hasPar...           3
# 160  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 161  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 162  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 163  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 164  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 165  {'roomNumber': '2', 'bathNumber': '1', 'hasLif...           2
# 166  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 167  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 168  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 169  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 170  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 171  {'roomNumber': '5', 'bathNumber': '5', 'hasPar...           5
# 172  {'roomNumber': '6', 'bathNumber': '4', 'hasPar...           6
# 173  {'roomNumber': '6', 'bathNumber': '4', 'hasPar...           6
# 174  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 175  {'roomNumber': '3', 'bathNumber': '2', 'hasPar...           3
# 176  {'roomNumber': '6', 'bathNumber': '3', 'hasPar...           6
# 177  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 178  {'roomNumber': '2', 'bathNumber': '2', 'hasLif...           2
# 179  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 180  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 181  {'roomNumber': '3', 'bathNumber': '1', 'hasPar...           3
# 182  {'roomNumber': '3', 'bathNumber': '3', 'hasPar...           3
# 183  {'roomNumber': '4', 'bathNumber': '3', 'hasPar...           4
# 184  {'roomNumber': '4', 'bathNumber': '2', 'hasPar...           4
# 185  {'roomNumber': '3', 'bathNumber': '2', 'hasLif...           3
# 186  {'roomNumber': '4', 'bathNumber': '3', 'hasPar...           4
#
#     bath_number has_garden has_terrace has_parking has_swimmingpool has_lift  \
# 0             3          1           1           1                1     None
# 1             2          1           1           1                1     None
# 2             4          1           1           0                1     None
# 3             2          1           1           1                1        1
# 4             2          0           1           1                1        1
# 5             2          0           1           1                1        1
# 6             4          1           1           1                1     None
# 7             2          0           0           1                1     None
# 8             4          1           1           1                1     None
# 9             3       None           1           1                1     None
# 10            3          1           1           1                1     None
# 11            3          1           1           1                1     None
# 12            4          1           1           1                1     None
# 13            3          1           1           1             None     None
# 14            3          1           1           1                1        1
# 15            1       None           1        None             None     None
# 16            3       None        None        None                1     None
# 17            6          1           1           1                1     None
# 18            2       None           1        None             None     None
# 19            2          1           1           1                1        1
# 20            2          1           1           1                1        1
# 21            1       None        None        None             None        1
# 22            4          1           1           0                1     None
# 23            2          0           1           1                1        1
# 24            2          0           1           1                1        1
# 25            2          0           1           1                1     None
# 26            2          1           1        None             None     None
# 27            1       None           1        None             None     None
# 28            8          1           1           1                1     None
# 29            5          1           1           1                1     None
# ..          ...        ...         ...         ...              ...      ...
# 157           2          1           1           1                1        1
# 158           2          0           1           1                1        1
# 159           3          1           0           1                1     None
# 160           2          0           1           1                1        1
# 161           2          0           1           1                1        1
# 162           2          0           1           1                1        1
# 163           2          0           1           1                1        1
# 164           2          0           1           1                1        1
# 165           1          1        None        None                1        1
# 166           2          1           0           1                1        1
# 167           2          1           0           1                1        1
# 168           2          1           0           1                1        1
# 169           2          0           1           1                1        1
# 170           2          0           1           1                1        1
# 171           5          1           1           1                1     None
# 172           4          1           1           1                1     None
# 173           4          1           1           1                1     None
# 174           2          1           1           1                1        1
# 175           2          1           1           1                1     None
# 176           3          1           1           1                1     None
# 177           2          0           1           1                1        1
# 178           2          0           1           1                1        1
# 179           2          0           1           1                1        1
# 180           2          1           1           1                1        1
# 181           1       None           1           0             None     None
# 182           3          1           1           1                1     None
# 183           3          1           1           1                0     None
# 184           2          1           1           1                1     None
# 185           2          1           1           1                1        0
# 186           3       None           1           1                1     None
#
#     constructed_area is_new_development is_needs_renovating is_goog_condition
# 0                194                  0                   0                 1
# 1                310                  0                   0                 1
# 2                410                  0                   0                 1
# 3                236                  1                   0                 0
# 4                150                  1                   0                 0
# 5                 99                  1                   0                 0
# 6                702                  0                   1                 0
# 7                149                  0                   0                 1
# 8                649                  0                   0                 1
# 9                152                  0                   0                 1
# 10               152                  0                   0                 1
# 11               338                  0                   0                 1
# 12               265                  0                   0                 1
# 13               298                  0                   0                 1
# 14               133                  0                   0                 1
# 15               179                  0                   0                 1
# 16               257                  0                   0                 1
# 17               290                  0                   0                 1
# 18               153                  0                   1                 0
# 19               116                  0                   0                 1
# 20               102                  0                   0                 1
# 21               103                  0                   0                 1
# 22               410                  0                   0                 1
# 23               101                  1                   0                 0
# 24                83                  1                   0                 0
# 25               160                  0                   0                 1
# 26               115                  0                   0                 1
# 27                80                  0                   0                 1
# 28              2500                  0                   0                 1
# 29               407                  0                   0                 1
# ..               ...                ...                 ...               ...
# 157              236                  1                   0                 0
# 158              118                  1                   0                 0
# 159              139                  1                   0                 0
# 160              117                  1                   0                 0
# 161              116                  1                   0                 0
# 162              125                  1                   0                 0
# 163              111                  1                   0                 0
# 164              112                  1                   0                 0
# 165              102                  0                   0                 1
# 166              119                  1                   0                 0
# 167              125                  1                   0                 0
# 168              116                  1                   0                 0
# 169              130                  1                   0                 0
# 170              118                  1                   0                 0
# 171             1004                  0                   0                 1
# 172              296                  0                   0                 1
# 173              380                  0                   0                 1
# 174              118                  0                   0                 1
# 175              116                  0                   0                 1
# 176              351                  0                   0                 1
# 177              109                  1                   0                 0
# 178               94                  1                   0                 0
# 179              109                  1                   0                 0
# 180              118                  0                   0                 1
# 181              179                  0                   0                 1
# 182              140                  0                   0                 1
# 183              226                  0                   0                 1
# 184              310                  0                   0                 1
# 185              123                  0                   0                 1
# 186              202                  0                   0                 1
#
# [187 rows x 18 columns]

# %%
df_inmuebles.to_csv('info-churriana-malaga.csv')
